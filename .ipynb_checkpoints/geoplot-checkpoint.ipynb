# %% [markdown]
# Pythonの<code>geoplot</code>のチュートリアルを動かしてみます。
# なお、多少冗長に書き直しています。
#
# 参考: https://nbviewer.jupyter.org/github/ResidentMario/geoplot/blob/master/notebooks/tutorials/Quickstart.ipynb
#
# 本ノートブックで利用する<code>geopandas</code>や<code>geoplot</code>は<code>anaconda (conda install)</code>で入れた方が良いと思います。
# <code>geoplot</code>は<code>pip</code>でも頑張れば入れられるらしいですが、私には無理でした。
# 一方<code>quilt</code>は<code>pip</code>のみ対応しています。
#
# 動作確認:
# Python: 3.7.3
# geopandas: 0.4.1
# geoplot: 0.2.4
# matplotlib: 3.0.3

# %% [markdown]
# # 準備

# %%
# 本ノートブックで利用するライブラリをインストールするには、このセルのコマンドを実行します
# ! conda install geopandas
# ! conda install geoplot
# ! pip install quilt

# %%
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt

# plt.show()を自動的にしてくれる
# %matplotlib inline

# %% [markdown]
# ここでは<code>GeoDataFrame</code>形式に格納されたのデータを扱います。この形式は基本的には<code>pandas</code>の<code>DataFrame</code>と一緒です。
# 違いは<code>shapely.geometry</code>型のデータを持つことを明記しているかどうかくらいです。
# この型は空間中の点やポリゴンの情報などを表現しています。

# %% [markdown]
# データセットを用意します。
# ここで、チュートリアルではいきなり
# <code>from quilt.data.ResidentMario import geoplot_data</code>
# としていますが、これでは通りません。
# 下のセルのように実行します。
# 参考: https://github.com/ResidentMario/geoplot/issues/41#issuecomment-341594813

# %%
import quilt
quilt.install("ResidentMario/geoplot_data")
from quilt.data.ResidentMario import geoplot_data
# Out:
# Downloading package metadata...
# ResidentMario/geoplot_data already installed.
# Overwrite? (y/n) y
# Fragments already downloaded

# %% [markdown]
# # 点プロット（都市人口基準）

# %% [markdown]
# アメリカの都市を、その人口の大きさに基づいてプロットしてみましょう。

# %% [markdown]
# アメリカの人口10万以上の都市の情報を得ます。

# %%
continental_cities=gpd.read_file(geoplot_data.usa_cities()).query("POP_2010 > 100000")
print("continental_cities.shape = ", continental_cities.shape)
continental_cities.head()
# Out:
# continental_cities.shape =  (284, 5)
#      id  POP_2010  ELEV_IN_FT STATE  \
# 3   177  105549.0       902.0    ND
# 30  373  210565.0       505.0    NY
# 34  378  145170.0       397.0    NY
# 39  386  261310.0       600.0    NY
# 61  426  106519.0       118.0    MA
#
#                                         geometry
# 3   POINT (-96.78980339999998 46.87718630000012)
# 30  POINT (-77.61555679999998 43.15478450000012)
# 34  POINT (-76.14742439999998 43.04812210000017)
# 39   POINT (-78.87836889999994 42.8864468000001)
# 61  POINT (-71.31617179999989 42.63342470000003)

# %% [markdown]
# <注意>ここで<code>geopandas</code>や<code>geoplot</code>では座標の値は（経度、緯度）の順で持っていますので、プロットの位置がおかしいと感じたらまずそこを確認しましょう。

# %% [markdown]
# それでは、<code>geoplot.pointplot()</code>で点をプロットしてみます。
# 引数には<code>shapely.geometry.point.Point</code>をデータフレームとして格納したものを入れます。

# %%
gplt.pointplot(continental_cities)

# %% [markdown]
# 点のプロット自体はできました。
# より場所を分かりやすくするために、アメリカの地図（州の境界線付き）上にプロットしてみましょう。
# 各州の情報を得ます。

# %%
contiguous_usa=gpd.read_file(geoplot_data.contiguous_usa())
print("contiguous_cities.shape = ", contiguous_usa.shape)
contiguous_usa.head()
# Out:
# contiguous_cities.shape =  (49, 4)
#   id adm1_code         State  \
# 0  0  USA-3514     Minnesota
# 1  1  USA-3515       Montana
# 2  2  USA-3516  North Dakota
# 3  4  USA-3518         Idaho
# 4  5  USA-3519    Washington
#
#                                             geometry
# 0  POLYGON ((-89.59940899999999 48.010274, -89.48...
# 1  POLYGON ((-111.194189 44.561156, -111.291548 4...
# 2  POLYGON ((-96.601359 46.351357, -96.5389080000...
# 3  POLYGON ((-111.049728 44.488163, -111.050245 4...
# 4  POLYGON ((-116.998073 46.33017, -116.906528 46...

# %% [markdown]
# <code>geoplot.polyplot()</code>でポリゴンをプロットできます。
# 引数には<code>shapely.geometry.polygon.Polygon</code>をデータフレームの形に格納したものを入れます。

# %%
gplt.polyplot(contiguous_usa)

# %% [markdown]
# 確かにアメリカの地図を表示できました。
# それではこの地図上に上の点群をプロットします。

# %%
ax=gplt.polyplot(contiguous_usa)
gplt.pointplot(continental_cities,ax=ax)

# %% [markdown]
# 確かにプロットできました。
# 人口10万人以上の都市は南西と北東部に多いように見えます。

# %% [markdown]
# プロットはできたのですが、このアメリカの形は少し奇妙です。
# 地球儀で見たものと違う気がします。
# というのも、球体上にあるものを平面状に投影すると形が変わってしまいます。  特にこれまでやってきた方法は雑な投影をしてしまっています。。。
# 代わりにアメリカの地図を描くときにより一般的なアルベルス正積円錐図法(Albers equal area projection)で描いてみましょう。

# %%
proj=gcrs.AlbersEqualArea()
ax=gplt.polyplot(contiguous_usa,projection=proj)
gplt.pointplot(continental_cities,ax=ax,projection=proj)

# %% [markdown]
# よりいつものアメリカの形に投影できました。
# この他にもさまざまな投影手法が<code>geoplot.crs</code>に実装されています。

# %% [markdown]
# <code>geoplot</code>ではこの他にも様々なカスタマイズができます。
# 下のセルでは各都市を、人口の大きさに比例した大きさの丸で表示します。

# %%
proj=gcrs.AlbersEqualArea()
ax=gplt.polyplot(contiguous_usa,
                projection=proj,
                zorder=-1,
                linewidth=0.5,
                figsize=(12,12))

gplt.pointplot(continental_cities,
               # 円の大きさ・色味・淵の線に関するパラメータ
              scale="POP_2010", # 円の大きさの基準
              limits=(1,80), # 描画する円の大きさは、最大でも最小のものの80倍とする
              hue="POP_2010", # 円の色味の基準
              cmap="Blues", # 色のグラデーションの基準色
              k=5, # 色は何段階の濃さにするか
              linewidth=0.5, # 円の淵の線の太さ
              edgecolor="black", # 円の淵の線の色
               # 凡例
              legend=True, # 凡例の表示するかどうか
              legend_var="scale", # 凡例の大きさの基準
              legend_values=[8000000,6000000,4000000,2000000,100000], # 凡例の値の範囲
              legend_labels=["8 million","6 million","4 million","2 million", "100 thousand"], # 凡例のラベル、範囲と対応
              legend_kwargs={"frameon":False, # 凡例の部分の枠線ありかなしか
                             "loc":"lower right"}, # 凡例の位置
              
               ax=ax,projection=proj)
ax.set_ylim((-1597757, 1457718)) # 地図の範囲南北端

plt.title("Cities in the contiguous United States, 2010")
# Out:
# Text(0.5, 1.0, 'Cities in the contiguous United States, 2010')

# %% [markdown]
# 確かに大きさの異なる円を描けました。
# サンフランシスコ、ロサンゼルス、シカゴ、ニューヨークあたりが大きいですね。直観とも沿っています。

# %% [markdown]
# # 点プロット、交通事故件数基準

# %% [markdown]
# ニューヨーク交通事故のあった箇所をプロットしてみましょう。

# %%
collisions=gpd.read_file(geoplot_data.nyc_collision_factors())
print("collisions.shape = ",collisions.shape)
collisions.head(3)
# Out:
# collisions.shape =  (7303, 31)
#    id  ON STREET NAME  NUMBER OF MOTORIST KILLED  \
# 0  18  WORTMAN AVENUE                          0
# 1  21   HUBERT STREET                          0
# 2  69    HENRY STREET                          0
#
#   CONTRIBUTING FACTOR VEHICLE 3  NUMBER OF CYCLIST INJURED  LONGITUDE  \
# 0                          None                          0 -73.872007
# 1                          None                          0 -74.008344
# 2                          None                          0 -73.997563
#
#   OFF STREET NAME VEHICLE TYPE CODE 4   LATITUDE                   LOCATION  \
# 0            None                None  40.662514  (40.6625139, -73.8720068)
# 1            None                None  40.721323  (40.7213228, -74.0083444)
# 2            None                None  40.687999  (40.6879989, -73.9975625)
#
#    ... ZIP CODE  VEHICLE TYPE CODE 3  NUMBER OF CYCLIST KILLED        DATE  \
# 0  ...  11208.0                 None                         0  11/10/2016
# 1  ...  10013.0                 None                         0  11/10/2016
# 2  ...  11201.0                 None                         0  04/16/2016
#
#   UNIQUE KEY  CONTRIBUTING FACTOR VEHICLE 5 VEHICLE TYPE CODE 5      TIME  \
# 0    3559576                           None                None  16:11:00
# 1    3557391                           None                None  05:11:00
# 2    3419378                           None                None  09:15:00
#
#   NUMBER OF PEDESTRIANS INJURED                                      geometry
# 0                             0  POINT (-73.87200679999999 40.66251389999999)
# 1                             1                POINT (-74.0083444 40.7213228)
# 2                             0                POINT (-73.9975625 40.6879989)
#
# [3 rows x 31 columns]

# %% [markdown]
# 重大な事故のデータも得ておきます。

# %%
injurious_collisions=gpd.read_file(geoplot_data.nyc_injurious_collisions())
print("injurious_collisions.shape = ",injurious_collisions.shape)
injurious_collisions.head(3)
# Out:
# injurious_collisions.shape =  (20644, 4)
#    id  NUMBER OF PERSONS INJURED    BOROUGH  \
# 0  11                          1   BROOKLYN
# 1  21                          1  MANHATTAN
# 2  27                          1   BROOKLYN
#
#                                geometry
# 0  POINT (-73.94268479999999 40.676495)
# 1        POINT (-74.0083444 40.7213228)
# 2        POINT (-73.9707643 40.6876384)

# %% [markdown]
# 行政区の地理情報を取得します。

# %%
boroughs=gpd.read_file(geoplot_data.nyc_boroughs())
print("boroughs.shape = ",boroughs.shape)
boroughs.head(3)
# Out:
# boroughs.shape =  (5, 5)
#    BoroCode       BoroName    Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330385.03697  1.623853e+09
# 1         4         Queens  861038.47930  3.049947e+09
# 2         3       Brooklyn  726568.94634  1.959432e+09
#
#                                             geometry
# 0  (POLYGON ((-74.05050806403247 40.5664220341608...
# 1  (POLYGON ((-73.83668274106708 40.5949466970158...
# 2  (POLYGON ((-73.8670614947212 40.58208797679338...

# %% [markdown]
# それではプロットしてみましょう。

# %%
gplt.pointplot(collisions)

# %% [markdown]
# そもそも交通事故の件数が多すぎて把握できませんね。
# 件数に基づいてグラデーションで表示してみましょう。

# %% [markdown]
# # グラデーション（交通事故件数基準）

# %%
proj=gcrs.AlbersEqualArea()
ax=gplt.polyplot(boroughs,projection=proj)
gplt.kdeplot(collisions,ax=ax,
             shade=True,
             shade_lowest=False,
             clip=boroughs.geometry,
             color="green",
             projection=proj)

# %% [markdown]
# <code>geoplot.voronoi</code>でも同様のことができます。

# %%
ax=gplt.voronoi(injurious_collisions.head(1000),
                        hue="NUMBER OF PERSONS INJURED",
                        cmap="Reds",
                        edgecolor="white",
                        clip=boroughs.geometry,
                        linewidth=0.5,
                        categorical=True,
                        #ax=ax,
                        projection=proj
                        )
gplt.polyplot(boroughs,linewidth=1,ax=ax,projection=proj)

# %% [markdown]
# ここで、これまでと違って点をプロットした後にポリゴンをプロットしているのは、描画の都合です。今まで通りの順番でやってもプロット自体はできます。

# %% [markdown]
# プロットするのは点でなくても形は州や国でもできます。
# その際は<code>choropleth</code>を使います。
# ちなみにchoroplethは階級区分図という意味です。

# %% [markdown]
# # グラデーション（白人割合基準）

# %% [markdown]
# それでは調査の区分の地理データを読み込みます。

# %%
census_tracts=gpd.read_file(geoplot_data.ny_census_partial())
print("census_tracks.shape = ",census_tracts.shape)
census_tracts.head(3)
# Out:
# census_tracks.shape =  (67, 4)
#   id  POP2000   WHITE                                           geometry
# 0  0   111931  105782  POLYGON ((-74.712396 44.953008, -74.7111320000...
# 1  1    79894   74562  POLYGON ((-74.025026 44.980036, -74.0274011055...
# 2  2    51134   42970  POLYGON ((-74.025026 44.980036, -74.021078 44....

# %% [markdown]
# 白人の割合を算出しておきます。

# %%
percent_white = census_tracts['WHITE'] / census_tracts['POP2000'] # 人口に占める白人の割合

# %% [markdown]
# 白人の割合の階級区分図を描きます。

# %%
gplt.choropleth(census_tracts, 
                hue=percent_white, # 白人の割合で色味を決める
                cmap='Purples', # 色は紫
                k=None, # 色味は相対的な段階には分けない
                legend=True, # 凡例を載せる
                projection=proj, # 投影
               )

# %% [markdown]
# 今回の色味は相対的な段階に分けずに絶対的な値に基づくように、パラメータを<code>k=None</code>としました。
# いかにニューヨークに白人が多いかがわかります。
# 他にも、面積の大きさを値の大きさに対応させる方法もあります。
# これは<code>cartogram</code>で実現できます。

# %% [markdown]
# # 面積可変（肥満度基準）

# %% [markdown]
# 試しにアメリカの州ごとに、肥満度を見てみましょう。
# まずは肥満度のデータを取得します。

# %%
obesity=geoplot_data.obesity_by_state()
obesity=obesity.rename(columns={"Percent":"Obesity Rate"})
print("obesity.shape = ",obesity.shape)
obesity.head()
# Out:
# obesity.shape =  (51, 2)
#       State  Obesity Rate
# 0   Alabama          32.4
# 1  Missouri          30.4
# 2    Alaska          28.4
# 3   Montana          24.6
# 4   Arizona          26.8

# %% [markdown]
# この州ごとの肥満度のデータを、州の位置・形と対応させます。
# そのために州の地理情報を持つ<code>contiguous_usa</code>と、<code>State</code>をキーとしてマージさせます。
# このマージにはの<code>dataframe.merge</code>みたいに<code>geodataframe.merge</code>が使えます。
# ここではこれを使います。
# チュートリアルではその代わりに<code>query</code>を使っています。

# %%
contiguous_usa=contiguous_usa.merge(obesity,how="left",on="State")
print("contiguous_usa.shape = ",contiguous_usa.shape)
contiguous_usa.head(3)
# Out:
# contiguous_usa.shape =  (49, 5)
#   id adm1_code         State  \
# 0  0  USA-3514     Minnesota
# 1  1  USA-3515       Montana
# 2  2  USA-3516  North Dakota
#
#                                             geometry  Obesity Rate
# 0  POLYGON ((-89.59940899999999 48.010274, -89.48...          25.5
# 1  POLYGON ((-111.194189 44.561156, -111.291548 4...          24.6
# 2  POLYGON ((-96.601359 46.351357, -96.5389080000...          31.0

# %% [markdown]
# それではプロットします。

# %%
gplt.cartogram(contiguous_usa, 
               scale='Obesity Rate', # 肥満率を基準に
               limits=(0.6, 1), # 1=元のサイズ、最小でも元の0.6倍の大きさ
               facecolor='Tomato', # トマト色
               trace_kwargs={'linewidth': 0.5}, # 州の元サイズの境界線の太さ
               projection=proj
              )

# %% [markdown]
# # 線描画（乗降客数基準）

# %% [markdown]
# これまで静的な場所についてプロットしてきました。
# それらの間を結ぶ線をプロットしたいときもあります。
# 例えば人の動きだったり交通だったりです。
# これは<code>sankey</code>でできます。
# sankeyはものの量の流れを表現できるsankey diagramのことらしいです。

# %% [markdown]
# それではロサンゼルスのフライトについて試してみましょう。

# %%
la_flights=gpd.read_file(geoplot_data.la_flights())
print("la_flights.shape = ",la_flights.shape)
la_flights.head(3)
# Out:
# la_flights.shape =  (42, 5)
#   id        Destination           Origin  Passengers  \
# 0  3  San Francisco, CA  Los Angeles, CA     1863155
# 1  5       New York, NY  Los Angeles, CA     1698805
# 2  7        Chicago, IL  Los Angeles, CA     1600612
#
#                                             geometry
# 0  (POINT (-118.2437 34.0522), POINT (-122.419415...
# 1  (POINT (-118.2437 34.0522), POINT (-74.0055244...
# 2  (POINT (-118.2437 34.0522), POINT (-87.6297982...

# %% [markdown]
# geometryの項目に、出発地と到着地の経度緯度があります。
# これらをそれぞれ抽出します。

# %%
la_flights=la_flights.assign(
    start=la_flights.geometry.map(lambda mp:mp[0]), # geometryの[0]をstartとして新たな項目に
    end=la_flights.geometry.map(lambda mp:mp[1]) # geometryの[1]をendとして新たな項目に
)

# %% [markdown]
# それでは描画します。

# %%
gplt.sankey(la_flights, 
            start='start', # 出発地
            end='end', # 到着地
            scale='Passengers', # 乗客数を基準に線の太さを決める
            hue='Passengers', # 乗客数を基準に線の色味を決める
            cmap='Purples', # 色味は紫 
            projection=proj 
           )
ax = plt.gca() # 現在のaxesを設定
ax.set_global() #世界全体を描画
ax.outline_patch.set_visible(True) #  地図の枠線を表示
ax.coastlines() # 国の海岸線を描画

# %% [markdown]
# 確かにフライトの線を描画できました。

# %% [markdown]
# 本チュートリアルは以上です。
